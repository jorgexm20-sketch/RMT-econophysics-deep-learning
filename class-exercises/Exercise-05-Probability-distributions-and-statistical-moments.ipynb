# %% [markdown]
# # Ejercicio 5 Distribuciones de probabilidad y sus momentos estadísticos

# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.linalg import sqrtm

# %% [markdown]
# Generamos 10000 números aleatorios con distribución normal, uniforme, y exponencial.

# %%
numeros = 10000
d_normal = np.random.normal(0, 1, numeros)
d_uniforme = np.random.uniform(0, 1, numeros)
d_exponencial = np.random.exponential(scale=1, size=numeros)

# %%
distribucion_aleatorios = [d_normal, d_uniforme,d_exponencial ]
media = [[], [], []]
desviasion_estandar = [[], [], []]
varianza = media = [[], [], []]
asimetria = media = [[], [], []]

# %%
for i in range(3):
    media[i].append(np.mean(distribucion_aleatorios[i]))
    desviasion_estandar[i].append(np.std(distribucion_aleatorios[i]))
    desviasion_estandar[i].append(np.var(distribucion_aleatorios[i]))
# Out:
# [[np.float64(0.0009404143254341209)],
#  [np.float64(0.5011918861354193)],
#  [np.float64(0.9977620543906492)]]

# %%
asimetria =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 asimetria = np.mean((d_normal - media[0])**3)/ desviasion_estandar[0]**3
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'
